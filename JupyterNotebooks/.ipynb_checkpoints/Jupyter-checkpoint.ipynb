# %% [markdown]
# # Rain prediction in Australia

# %% [markdown]
# <img src="../images/1786.webp" height=500 width=700>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier


import os
import sys

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
from tools import fill_missing_values, create_month, print_missing
from tools import assessClassifier, assessClassifier_cv, testClassifier
from tools import modify_data

# %% [markdown]
# ***
# # Define supporting function
# ***

# %%
def convert_to_numeric(val):
    if val == "No":
        return 0
    else:
        return 1

# %%
import warnings
warnings.filterwarnings('ignore') # suppress warnings

# %% [markdown]
# # 1. Load and Research the Data

# %%
df = pd.read_csv('../data/weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
corr_matrix = df.corr()
corr_matrix # print correlation matrix
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# Humidity3pm    0.006089 -0.508855  0.255755    -0.390243 -0.629130
# Pressure9am   -0.450970 -0.332061 -0.168154    -0.270362  0.041970
# Pressure3pm   -0.461292 -0.427167 -0.126534    -0.293581 -0.019719
# Cloud9am       0.078754 -0.289370  0.198528    -0.183793 -0.675323
# Cloud3pm       0.021605 -0.277921  0.172403    -0.182618 -0.703930
# Temp9am        0.901821  0.887210  0.011192     0.545115  0.291188
# Temp3pm        0.708906  0.984503 -0.079657     0.572893  0.490501
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.177415      0.175064      0.175173    -0.232899
# MaxTemp             0.067615      0.014450      0.050300    -0.504110
# Rainfall            0.133659      0.087338      0.057887     0.224405
# Evaporation         0.203021      0.193084      0.129400    -0.504092
# Sunshine           -0.034750      0.005499      0.053834    -0.490819
# WindGustSpeed       1.000000      0.605303      0.686307    -0.215070
# WindSpeed9am        0.605303      1.000000      0.519547    -0.270858
# WindSpeed3pm        0.686307      0.519547      1.000000    -0.145525
# Humidity9am        -0.215070     -0.270858     -0.145525     1.000000
# Humidity3pm        -0.026327     -0.031614      0.016432     0.666949
# Pressure9am        -0.458744     -0.228743     -0.296351     0.139442
# Pressure3pm        -0.413749     -0.175817     -0.255439     0.186858
# Cloud9am            0.071736      0.025112      0.053337     0.452297
# Cloud3pm            0.109168      0.054639      0.025396     0.357326
# Temp9am             0.150150      0.128545      0.163030    -0.471354
# Temp3pm             0.032748      0.004569      0.027778    -0.498399
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp           0.006089    -0.450970    -0.461292  0.078754  0.021605
# MaxTemp          -0.508855    -0.332061    -0.427167 -0.289370 -0.277921
# Rainfall          0.255755    -0.168154    -0.126534  0.198528  0.172403
# Evaporation      -0.390243    -0.270362    -0.293581 -0.183793 -0.182618
# Sunshine         -0.629130     0.041970    -0.019719 -0.675323 -0.703930
# WindGustSpeed    -0.026327    -0.458744    -0.413749  0.071736  0.109168
# WindSpeed9am     -0.031614    -0.228743    -0.175817  0.025112  0.054639
# WindSpeed3pm      0.016432    -0.296351    -0.255439  0.053337  0.025396
# Humidity9am       0.666949     0.139442     0.186858  0.452297  0.357326
# Humidity3pm       1.000000    -0.027544     0.051997  0.517120  0.523120
# Pressure9am      -0.027544     1.000000     0.961326 -0.129796 -0.147861
# Pressure3pm       0.051997     0.961326     1.000000 -0.060772 -0.084778
# Cloud9am          0.517120    -0.129796    -0.060772  1.000000  0.603564
# Cloud3pm          0.523120    -0.147861    -0.084778  0.603564  1.000000
# Temp9am          -0.221019    -0.422556    -0.470187 -0.136959 -0.126659
# Temp3pm          -0.557841    -0.286770    -0.389548 -0.302060 -0.317420
#
#                 Temp9am   Temp3pm
# MinTemp        0.901821  0.708906
# MaxTemp        0.887210  0.984503
# Rainfall       0.011192 -0.079657
# Evaporation    0.545115  0.572893
# Sunshine       0.291188  0.490501
# WindGustSpeed  0.150150  0.032748
# WindSpeed9am   0.128545  0.004569
# WindSpeed3pm   0.163030  0.027778
# Humidity9am   -0.471354 -0.498399
# Humidity3pm   -0.221019 -0.557841
# Pressure9am   -0.422556 -0.286770
# Pressure3pm   -0.470187 -0.389548
# Cloud9am      -0.136959 -0.302060
# Cloud3pm      -0.126659 -0.317420
# Temp9am        1.000000  0.860591
# Temp3pm        0.860591  1.000000

# %%
new_df = df.copy()
new_df.RainTomorrow = df.RainTomorrow.apply(convert_to_numeric).copy()
new_df.RainTomorrow.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: RainTomorrow, dtype: int64

# %%
#sns.pairplot(new_df[:2000]) # Build pair plot for first 2000 values(otherwise takes too long)

# %%
fontsize = 20;

# %%
plt.figure(figsize=(15, 8));
plt.title("Number  Rainy Days",fontsize=fontsize);
df.RainTomorrow.hist();
plt.xlabel("Rain: No/Yes",fontsize=fontsize)
plt.ylabel("Number of Days", fontsize=fontsize)
plt.show()

# %%
create_month(new_df)

# %%
r = new_df.groupby('Month')['RainTomorrow'].sum()
r = r.reset_index()
r
plt.figure(figsize=(15,8));
plt.bar(r.Month,r.RainTomorrow);
plt.title("Number of Rainy Days by Month",fontsize=fontsize);
plt.show()

# %% [markdown]
# **Comments on the pairplots: There are few linear relations with high values of the r pearson coefficient.**

# %% [markdown]
# ***
# # Split the data to put a test dataset away and not use it until the very end
# ***

# %%
X = df.drop('RainTomorrow',axis=1) # Create the data without target column
y = df.RainTomorrow # assign the target column
X_short = X.sample(frac=1)
y_short = y[list(X_short.index)]
X_train, X_test, y_train, y_test = train_test_split(X_short, y_short, test_size=0.3, random_state=0) # split the data into train/test datasets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %% [markdown]
# ***
# # End of Splitting Data
# ***

# %% [markdown]
# ***
# # Prepare Data
# ***

# %% [markdown]
# ***
# ### It seems logical to create a column with the "Month" and drop the column with the "Date". I will call create_month function to do that.
# ***

# %%
create_month(X_train)
X_train.head() # Check the result
# Out:
#          Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 104091  Nuriootpa      NaN     12.0       0.0          2.0       8.8
# 7105        Cobar     16.2     34.6       1.6          7.6       NaN
# 104273  Nuriootpa      9.7     27.8       0.0          8.2      12.4
# 78220    Watsonia     10.2     19.0       3.4          6.0       6.3
# 80800    Watsonia     10.9     20.3       0.0          4.6      10.2
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 104091          SE           48.0        NaN         SE  ...          NaN
# 7105           ESE           30.0        NNE        SSE  ...         57.0
# 104273          SE           41.0          E        NNW  ...         55.0
# 78220            N           41.0        NaN          N  ...         99.0
# 80800           SW           28.0        WSW         SW  ...         63.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 104091         57.0          NaN       1020.4       NaN       3.0      NaN
# 7105           23.0       1011.9       1008.5       2.0       4.0     23.2
# 104273         19.0       1021.4       1018.2       6.0       6.0     15.7
# 78220          44.0       1018.4       1010.8       7.0       4.0     10.3
# 80800          50.0       1023.9       1022.6       7.0       2.0     13.3
#
#         Temp3pm  RainToday  Month
# 104091     11.5         No      6
# 7105       33.1        Yes     12
# 104273     26.3         No     12
# 78220      17.5        Yes      8
# 80800      19.3         No     12
#
# [5 rows x 22 columns]

# %% [markdown]
# ***
# # Dealing with missing values...
# ### Checking missing values: total and percent
# ***

# %%
print_missing(X_train) # Print number of missing values together with percent
# Out:
# **************************************************
#                Total   Percent
# Sunshine       34385  0.482427
# Evaporation    30923  0.433855
# Cloud3pm       29374  0.412122
# Cloud9am       27650  0.387934
# Pressure9am     7431  0.104258
# Pressure3pm     7411  0.103978
# WindDir9am      5199  0.072943
# WindGustDir     5040  0.070712
# WindGustSpeed   5015  0.070361
# Humidity3pm     2208  0.030979
# WindDir3pm      2090  0.029323
# Temp3pm         1788  0.025086
# Rainfall        1641  0.023024
# RainToday       1641  0.023024
# WindSpeed3pm    1496  0.020989
# Humidity9am     1323  0.018562
# Temp9am          902  0.012655
# WindSpeed9am     876  0.012290
# MinTemp          737  0.010340
# MaxTemp          635  0.008909
# Month              0  0.000000
# Location           0  0.000000
# **************************************************

# %% [markdown]
# ***
# ## There are a lot of missing values in nnunmerical columns.<br>
# * ## I don't want to drop all these values.
# * ## I am going to use the median of the values for this column with the same location and the same month to fill in the missing values.
# * ## I will, also, create an array called "save" with all the data that is inserted for missing values to use it later for the missing value for the test data that I put aside. "save" array is later converted into a data frame "saved_median" so it would be easier to use.
# ***

# %%
save = [] # preparing an empty array to store the median values we use here to re-use later for Test Data 
cols = [cl for cl in X_train.columns if X_train[cl].dtype in ['float64']] # Numerical Columns
for location in X_train.Location.unique():
    print(f"Working on Location: {location}")
    for month in X_train.Month.unique():
        save_info = [location]
        for column in cols:
            median_for_month = X_train[(X_train.Location == location) 
                                           & (X_train.Month == month)][column].median()
            if np.isnan(median_for_month):
                median_for_month = X_train[(X_train.Month == month)][column].median()
            idx = list(X_train[(X_train.Location == location)
                                     & (X_train.Month == month)
                                     & (X_train[column].isna())].index)
            X_train.loc[idx,column] = median_for_month
            save_info.append(median_for_month)
        save_info.append(month)
        save.append(save_info)
# Out:
# Working on Location: Nuriootpa
# Working on Location: Cobar
# Working on Location: Watsonia
# Working on Location: Newcastle
# Working on Location: SydneyAirport
# Working on Location: Richmond
# Working on Location: Williamtown
# Working on Location: AliceSprings
# Working on Location: Brisbane
# Working on Location: Launceston
# Working on Location: CoffsHarbour
# Working on Location: Albany
# Working on Location: BadgerysCreek
# Working on Location: PerthAirport
# Working on Location: Witchcliffe
# Working on Location: Adelaide
# Working on Location: Darwin
# Working on Location: Canberra
# Working on Location: Sydney
# Working on Location: Ballarat
# Working on Location: Mildura
# Working on Location: Hobart
# Working on Location: Woomera
# Working on Location: Walpole
# Working on Location: Nhil
# Working on Location: Dartmoor
# Working on Location: Katherine
# Working on Location: WaggaWagga
# Working on Location: MountGinini
# Working on Location: Cairns
# Working on Location: MountGambier
# Working on Location: MelbourneAirport
# Working on Location: Townsville
# Working on Location: Sale
# Working on Location: GoldCoast
# Working on Location: SalmonGums
# Working on Location: Tuggeranong
# Working on Location: Bendigo
# Working on Location: Albury
# Working on Location: Perth
# Working on Location: Moree
# Working on Location: Wollongong
# Working on Location: NorahHead
# Working on Location: Portland
# Working on Location: Melbourne
# Working on Location: Penrith
# Working on Location: NorfolkIsland
# Working on Location: PearceRAAF
# Working on Location: Uluru

# %%
X_train.head() # Check if everything went okay
# Out:
#          Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 104091  Nuriootpa      5.4     12.0       0.0          2.0       8.8
# 7105        Cobar     16.2     34.6       1.6          7.6      12.4
# 104273  Nuriootpa      9.7     27.8       0.0          8.2      12.4
# 78220    Watsonia     10.2     19.0       3.4          6.0       6.3
# 80800    Watsonia     10.9     20.3       0.0          4.6      10.2
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 104091          SE           48.0        NaN         SE  ...         86.0
# 7105           ESE           30.0        NNE        SSE  ...         57.0
# 104273          SE           41.0          E        NNW  ...         55.0
# 78220            N           41.0        NaN          N  ...         99.0
# 80800           SW           28.0        WSW         SW  ...         63.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 104091         57.0       1024.3       1020.4       6.5       3.0     9.45
# 7105           23.0       1011.9       1008.5       2.0       4.0    23.20
# 104273         19.0       1021.4       1018.2       6.0       6.0    15.70
# 78220          44.0       1018.4       1010.8       7.0       4.0    10.30
# 80800          50.0       1023.9       1022.6       7.0       2.0    13.30
#
#         Temp3pm  RainToday  Month
# 104091     11.5         No      6
# 7105       33.1        Yes     12
# 104273     26.3         No     12
# 78220      17.5        Yes      8
# 80800      19.3         No     12
#
# [5 rows x 22 columns]

# %%
saved_median = pd.DataFrame(save,columns=['Location']+cols+ ['Month']) # Save the values I used to fill in missing ones for later use as data frame
saved_median.head()
# Out:
#     Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  Nuriootpa     5.40    14.05       0.2         1.40      5.20
# 1  Nuriootpa    12.50    27.80       0.0         8.20     11.55
# 2  Nuriootpa     5.70    14.50       0.2         2.15      6.30
# 3  Nuriootpa     7.65    17.40       0.0         2.20      5.40
# 4  Nuriootpa    10.90    24.10       0.0         7.10     10.30
#
#    WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0           33.0           9.0          15.0         86.0         62.0
# 1           41.0          17.0          19.0         52.0         28.0
# 2           40.0          13.0          20.0         84.5         60.0
# 3           35.0           9.0          17.0         77.0         50.5
# 4           40.0          17.0          17.0         56.0         31.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  Month
# 0      1024.30      1021.80       6.5       6.0     9.45     13.2      6
# 1      1013.85      1011.95       4.0       5.0    18.15     25.5     12
# 2      1020.20      1018.95       6.0       6.0     9.45     13.1      8
# 3      1021.75      1019.60       6.0       6.0    12.15     16.1      5
# 4      1017.10      1014.90       6.0       6.0    15.50     22.7     11

# %% [markdown]
# ## Check how balanced the data is for the target column

# %%
y_train.value_counts()
# Out:
# No     54152
# Yes    15513
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# ## It is not balanced but it is not too bad

# %% [markdown]
# # 2. Data preprocessing

# %%
num_columns = [column for column in X_train.columns if X_train[column].dtype == 'float64'] # Save numerical columns into array so it is easier to use

# %%
num_pipline = Pipeline([
    ('std_scaler', StandardScaler()),
]) # Define a pipeline for scaling the data

# %%
X_train[num_columns] = num_pipline.fit_transform(X_train[num_columns])
X_train.head()
# Out:
#          Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 104091  Nuriootpa -1.065790 -1.582204 -0.275425    -0.905571  0.213206
# 7105        Cobar  0.626425  1.603284 -0.086681     0.692963  1.411975
# 104273  Nuriootpa -0.392038  0.644818 -0.275425     0.864235  1.411975
# 78220    Watsonia -0.313694 -0.595549  0.125656     0.236239 -0.619273
# 80800    Watsonia -0.204014 -0.412313 -0.275425    -0.163395  0.679393
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 104091          SE       0.617211        NaN         SE  ...     0.898643
# 7105           ESE      -0.750894        NNE        SSE  ...    -0.635286
# 104273          SE       0.085170          E        NNW  ...    -0.741074
# 78220            N       0.085170        NaN          N  ...     1.586267
# 80800           SW      -0.902905        WSW         SW  ...    -0.317921
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm   Temp9am  \
# 104091     0.262992     0.976305     0.761011  0.635145 -0.808858 -1.157504
# 7105      -1.386334    -0.852298    -1.010074 -1.181288 -0.371751  0.959549
# 104273    -1.580372     0.548648     0.433584  0.433319  0.502463 -0.195207
# 78220     -0.367633     0.106244    -0.667763  0.836971 -0.371751 -1.026632
# 80800     -0.076575     0.917318     1.088439  0.836971 -1.245965 -0.564729
#
#          Temp3pm  RainToday  Month
# 104091 -1.470693         No      6
# 7105    1.639954        Yes     12
# 104273  0.660677         No     12
# 78220  -0.606624        Yes      8
# 80800  -0.347404         No     12
#
# [5 rows x 22 columns]

# %% [markdown]
# ***
# ## Let's encode categorical features using one-hot-encoding.
# ***

# %%
ohe = pd.get_dummies(data=X_train, columns=['WindGustDir','WindDir9am','WindDir3pm','Location'],drop_first=True)
ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71275 entries, 104091 to 19170
# Columns: 111 entries, MinTemp to Location_Woomera
# dtypes: float64(16), int64(1), object(1), uint8(93)
# memory usage: 19.2+ MB

# %%
from sklearn import preprocessing

ohe['RainToday'] = X_train['RainToday'].astype(str)
ohe['RainTomorrow'] =y_train.astype(str)

lb = preprocessing.LabelBinarizer()

ohe['RainToday'] = lb.fit_transform(ohe['RainToday'])
ohe['RainTomorrow'] = lb.fit_transform(ohe['RainTomorrow'])

# %% [markdown]
# **Drop missing values and create target column y and data X**

# %%
ohe = ohe.dropna()
y_train = ohe['RainTomorrow']
X_train = ohe.drop(['RainTomorrow'], axis=1)

# %%
X_train.head()
# Out:
#          MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 104091 -1.065790 -1.582204 -0.275425    -0.905571  0.213206       0.617211
# 7105    0.626425  1.603284 -0.086681     0.692963  1.411975      -0.750894
# 104273 -0.392038  0.644818 -0.275425     0.864235  1.411975       0.085170
# 78220  -0.313694 -0.595549  0.125656     0.236239 -0.619273       0.085170
# 80800  -0.204014 -0.412313 -0.275425    -0.163395  0.679393      -0.902905
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 104091     -0.561823     -0.859714     0.898643     0.262992  ...
# 7105       -0.110626     -0.632244    -0.635286    -1.386334  ...
# 104273      0.340572     -1.087184    -0.741074    -1.580372  ...
# 78220      -1.577018      0.163901     1.586267    -0.367633  ...
# 80800      -0.900222     -0.632244    -0.317921    -0.076575  ...
#
#         Location_Townsville  Location_Tuggeranong  Location_Uluru  \
# 104091                    0                     0               0
# 7105                      0                     0               0
# 104273                    0                     0               0
# 78220                     0                     0               0
# 80800                     0                     0               0
#
#         Location_WaggaWagga  Location_Walpole  Location_Watsonia  \
# 104091                    0                 0                  0
# 7105                      0                 0                  0
# 104273                    0                 0                  0
# 78220                     0                 0                  1
# 80800                     0                 0                  1
#
#         Location_Williamtown  Location_Witchcliffe  Location_Wollongong  \
# 104091                     0                     0                    0
# 7105                       0                     0                    0
# 104273                     0                     0                    0
# 78220                      0                     0                    0
# 80800                      0                     0                    0
#
#         Location_Woomera
# 104091                 0
# 7105                   0
# 104273                 0
# 78220                  0
# 80800                  0
#
# [5 rows x 111 columns]

# %%
y_train.head()
# Out:
# 104091    1
# 7105      1
# 104273    1
# 78220     0
# 80800     1
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# ***
# ## Split the data into the training and validation parts
# ***

# %%
#X_train,X_val,y_train,y_val = train_test_split(X, y, test_size=0.3,random_state=0) 
#allValues = (X_train,X_val,y_train,y_val) # Create a tuple to send it as an argument to the function
allValues = (X_train[:1000],y_train[:1000]) # Create a tuple to send it as an argument to the function

# %%
str_columns= ['WindGustDir','WindDir9am','WindDir3pm','Location']

# %%
X_test, y_test = modify_data(X_test,y_test, saved_median,str_columns,num_columns,lb, num_pipline)
X_val, y_val = modify_data(X_val,y_val, saved_median,str_columns,num_columns,lb, num_pipline)
allValues= (X_train,X_val, y_train,y_val)
# Out:
# --------------------------------------------------
# Modifying Data
# --------------------------------------------------
# Workin on Location:  Albury
# Workin on Location:  Canberra
# Workin on Location:  Cairns
# Workin on Location:  Bendigo
# Workin on Location:  AliceSprings
# Workin on Location:  NorfolkIsland
# Workin on Location:  Moree
# Workin on Location:  Adelaide
# Workin on Location:  SalmonGums
# Workin on Location:  Tuggeranong
# Workin on Location:  GoldCoast
# Workin on Location:  Cobar
# Workin on Location:  Watsonia
# Workin on Location:  Townsville
# Workin on Location:  Ballarat
# Workin on Location:  Portland
# Workin on Location:  Mildura
# Workin on Location:  CoffsHarbour
# Workin on Location:  Nuriootpa
# Workin on Location:  Penrith
# Workin on Location:  Melbourne
# Workin on Location:  Nhil
# Workin on Location:  Uluru
# Workin on Location:  Witchcliffe
# Workin on Location:  Launceston
# Workin on Location:  PerthAirport
# Workin on Location:  NorahHead
# Workin on Location:  PearceRAAF
# Workin on Location:  BadgerysCreek
# Workin on Location:  MelbourneAirport
# Workin on Location:  Richmond
# Workin on Location:  MountGambier
# Workin on Location:  Williamtown
# Workin on Location:  Sydney
# Workin on Location:  Dartmoor
# Workin on Location:  SydneyAirport
# Workin on Location:  WaggaWagga
# Workin on Location:  Newcastle
# Workin on Location:  Sale
# Workin on Location:  MountGinini
# Workin on Location:  Hobart
# Workin on Location:  Perth
# Workin on Location:  Albany
# Workin on Location:  Woomera
# Workin on Location:  Walpole
# Workin on Location:  Wollongong
# Workin on Location:  Katherine
# Workin on Location:  Brisbane
# Workin on Location:  Darwin
# --------------------------------------------------
# Modifying Data
# --------------------------------------------------
# Workin on Location:  Penrith
# Workin on Location:  PearceRAAF
# Workin on Location:  Sydney
# Workin on Location:  Portland
# Workin on Location:  WaggaWagga
# Workin on Location:  Bendigo
# Workin on Location:  BadgerysCreek
# Workin on Location:  MelbourneAirport
# Workin on Location:  Brisbane
# Workin on Location:  Perth
# Workin on Location:  Wollongong
# Workin on Location:  Melbourne
# Workin on Location:  Williamtown
# Workin on Location:  AliceSprings
# Workin on Location:  MountGambier
# Workin on Location:  Darwin
# Workin on Location:  NorfolkIsland
# Workin on Location:  MountGinini
# Workin on Location:  Cairns
# Workin on Location:  Watsonia
# Workin on Location:  SydneyAirport
# Workin on Location:  Albany
# Workin on Location:  Sale
# Workin on Location:  Launceston
# Workin on Location:  Nuriootpa
# Workin on Location:  Tuggeranong
# Workin on Location:  Adelaide
# Workin on Location:  Walpole
# Workin on Location:  Ballarat
# Workin on Location:  Mildura
# Workin on Location:  Hobart
# Workin on Location:  Dartmoor
# Workin on Location:  Witchcliffe
# Workin on Location:  Richmond
# Workin on Location:  SalmonGums
# Workin on Location:  Newcastle
# Workin on Location:  Moree
# Workin on Location:  CoffsHarbour
# Workin on Location:  NorahHead
# Workin on Location:  Katherine
# Workin on Location:  PerthAirport
# Workin on Location:  Townsville
# Workin on Location:  Albury
# Workin on Location:  Woomera
# Workin on Location:  GoldCoast
# Workin on Location:  Cobar
# Workin on Location:  Uluru
# Workin on Location:  Nhil
# Workin on Location:  Canberra

# %% [markdown]
# ***
# ## Here I preprocess the Test Data that will not be used for training <br> but will be used at the end to test how well our model performs
# ***

# %%
X_test.head() # Check few rows to check if everything is fine
# Out:
#          MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 55      0.281715  1.560998 -0.275425     0.807144  0.912487      -1.206929
# 47082   0.673431  0.969005 -0.275425     0.807144  1.045684       0.465199
# 88754   1.331515  0.616628  0.408772    -0.220485 -1.085461       0.465199
# 58630  -0.204014 -0.045841 -0.275425    -0.391757  0.046710      -0.522876
# 138329 -0.987447 -0.200886 -0.275425     0.692963  0.912487       0.237182
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 55         -0.787422     -0.632244    -1.322909    -2.016958  ...
# 47082      -0.787422     -0.404774    -0.159239    -0.561671  ...
# 88754       0.678970     -0.404774     0.369702     1.087654  ...
# 58630       0.678970     -0.177304     0.369702    -0.173594  ...
# 138329      1.355767      0.391372    -1.851851    -1.192295  ...
#
#         Location_Townsville  Location_Tuggeranong  Location_Uluru  \
# 55                        0                     0               0
# 47082                     0                     0               0
# 88754                     0                     0               0
# 58630                     0                     0               0
# 138329                    0                     0               0
#
#         Location_WaggaWagga  Location_Walpole  Location_Watsonia  \
# 55                        0                 0                  0
# 47082                     0                 0                  0
# 88754                     0                 0                  0
# 58630                     0                 0                  0
# 138329                    0                 0                  0
#
#         Location_Williamtown  Location_Witchcliffe  Location_Wollongong  \
# 55                         0                     0                    0
# 47082                      0                     0                    0
# 88754                      0                     0                    0
# 58630                      0                     0                    0
# 138329                     0                     0                    0
#
#         Location_Woomera
# 55                     0
# 47082                  0
# 88754                  0
# 58630                  0
# 138329                 0
#
# [5 rows x 111 columns]

# %%
X_val.head()
# Out:
#          MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 24506   0.830118  0.687104 -0.204646     0.578782  0.745992      -0.522876
# 115738  1.441196  1.138146 -0.275425     0.521692  0.446300      -0.066841
# 30771   1.065148  0.038730 -0.275425     1.492230  0.679393       0.085170
# 76110  -0.517387 -0.468693 -0.228239    -0.791390 -0.519375       0.237182
# 39109  -0.407706  0.038730 -0.275425    -0.505938  0.845889      -0.522876
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 24506      -1.125821     -0.404774     0.422596     0.165972  ...
# 115738     -0.110626      1.073782    -0.053451     0.020444  ...
# 30771       0.340572      1.301252    -1.375803    -0.028066  ...
# 76110       0.114973      0.618842     0.739961     0.990635  ...
# 39109      -0.110626     -0.177304    -0.688180    -1.337824  ...
#
#         Location_Townsville  Location_Tuggeranong  Location_Uluru  \
# 24506                     0                     0               0
# 115738                    0                     0               0
# 30771                     0                     0               0
# 76110                     0                     0               0
# 39109                     0                     0               0
#
#         Location_WaggaWagga  Location_Walpole  Location_Watsonia  \
# 24506                     0                 0                  0
# 115738                    0                 0                  0
# 30771                     0                 0                  0
# 76110                     0                 0                  0
# 39109                     1                 0                  0
#
#         Location_Williamtown  Location_Witchcliffe  Location_Wollongong  \
# 24506                      0                     0                    0
# 115738                     0                     0                    0
# 30771                      0                     0                    0
# 76110                      0                     0                    0
# 39109                      0                     0                    0
#
#         Location_Woomera
# 24506                  0
# 115738                 0
# 30771                  0
# 76110                  0
# 39109                  0
#
# [5 rows x 111 columns]

# %% [markdown]
# # 3. Model building

# %% [markdown]
# ***
# # I create a bunch of baseline classifiers:
# * LogisticRegression()
# * RandomForestClassifier()
# * KNeighborsClassifier()
# * SVC()
# * XGBClassifier()
# * GaussianNB()
# ### I will train them and compare results based on <br> f1 score as a primary metric and precision as a secondary
# ***

# %%
clf_Logistic = LogisticRegression()
clf_Forest = RandomForestClassifier()
clf_KNN = KNeighborsClassifier()
clf_XGBoost = XGBClassifier()
clf_NaiveB = GaussianNB()

# %%
details = {'name':[],'f1':[],'precision':[],'recall':[],'roc_auc_score':[], 'accuracy':[]} # create empty dictionary to hold results
classifiers = [clf_Logistic, clf_Forest, clf_XGBoost, clf_NaiveB] # array of classifiers clf_KNN,
for clf in classifiers:#, clf_KNN,clf_SVC, clf_XGBoost, clf_NaiveB]: # use loop to train "vanilla" classifiers and update 'details'
    print(f"Working on {str(clf)}")
    results = assessClassifier(clf, allValues)
    clf.fit(allValues[0],allValues[2])
    y_pred = clf.predict(X_test)
    print("\n", "*"*50, "\nConfusion Matrix \n", confusion_matrix(y_test,y_pred), '\n')
    for item in results.keys():
        details[item].append(results[item])
# Out:
# Working on LogisticRegression()
#
#  **************************************************
# Confusion Matrix
#  [[ 5358  5168]
#  [ 2110 31002]]
#
# Working on RandomForestClassifier()
#
#  **************************************************
# Confusion Matrix
#  [[ 5473  5053]
#  [ 1652 31460]]
#
# Working on XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)
#
#  **************************************************
# Confusion Matrix
#  [[ 6045  4481]
#  [ 1982 31130]]
#
# Working on GaussianNB()
#
#  **************************************************
# Confusion Matrix
#  [[ 7351  3175]
#  [11968 21144]]

# %%
df = pd.DataFrame(details)
df # print results
# Out:
#                                                 name        f1  precision  \
# 0                               LogisticRegression()  0.894012   0.854858
# 1                           RandomForestClassifier()  0.902368   0.858766
# 2  XGBClassifier(base_score=None, booster=None, c...  0.903884   0.870510
# 3                                       GaussianNB()  0.735055   0.867513
#
#      recall  roc_auc_score  accuracy
# 0  0.936925       0.723833  0.832357
# 1  0.950633       0.734890  0.844764
# 2  0.939918       0.754949  0.849150
# 3  0.637689       0.669078  0.653092

# %%
# Plot roc curve to compare results
from sklearn.metrics import plot_roc_curve
ax = plt.gca()
for clf in classifiers:
    plot_roc_curve(clf, X_test, y_test, ax=ax)
plt.show()

# %% [markdown]
# ***
# #  Comments on Vanilla Classifiers
# ### I will use Logistic Regression, Random Forest, and XGB classifiers<br> for tune ups and comparison since the have the highest f1 scores.
# ***

# %%
# set values for the tune up common to all classifiers
cv = 5
scoring = 'f1'
values = (X_train, X_test, y_train, y_test)
random_state =10

# %% [markdown]
# # 4. Tune up models

# %% [markdown]
# ***
# ## Tune up Logistic Regression
# ***

# %%
# create the grid for  Logistic Regression
c_space = np.logspace(-10, 18, 30)
param_grid_LG = {'C': c_space,
    'penalty': ['l1', 'l2'],
    'max_iter': [100,500],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']}

# %%
# Perform optimizaton and print results
logistic = testClassifier(LogisticRegression(random_state=random_state),
                                            param_grid=param_grid_LG,
                                            scoring=scoring,
                                            values=values)
# Out:
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  6.2min
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 567, in run
#     self.flag_executor_shutting_down()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 756, in flag_executor_shutting_down
#     self.kill_workers()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 766, in kill_workers
#     recursive_terminate(p)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/utils.py", line 28, in recursive_terminate
#     _recursive_terminate_without_psutil(process)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/utils.py", line 53, in _recursive_terminate_without_psutil
#     _recursive_terminate(process.pid)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/utils.py", line 92, in _recursive_terminate
#     children_pids = subprocess.check_output(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/subprocess.py", line 411, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/subprocess.py", line 512, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['pgrep', '-P', '1327']' died with <Signals.SIGINT: 2>.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 940, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/concurrent/futures/_base.py", line 434, in result
#     self._condition.wait(timeout)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 1188, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 708, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 1061, in __call__
#     self.retrieve()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 962, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-3d404dfb6435>", line 2, in <module>
#     logistic = testClassifier(LogisticRegression(random_state=random_state),
#   File "/Users/yevgeniykostrov/Documents/Flatiron/Phase3_Project_Final/PredictRainKaggle/JupyterNotebooks/tools.py", line 165, in testClassifier
#     grid.fit(X_train,y_train)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 734, in __exit__
#     self._terminate_backend()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 764, in _terminate_backend
#     self._backend.terminate()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 551, in terminate
#     self._workers._temp_folder_manager._unlink_temporary_resources(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 627, in _unlink_temporary_resources
#     self._try_delete_folder(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 654, in _try_delete_folder
#     delete_folder(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/disk.py", line 136, in delete_folder
#     time.sleep(RM_SUBDIRS_RETRY_TIME)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 745, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 63, in ismodule
#     def ismodule(object):
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 940, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/concurrent/futures/_base.py", line 434, in result
#     self._condition.wait(timeout)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 1188, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 708, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 1061, in __call__
#     self.retrieve()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 962, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-3d404dfb6435>", line 2, in <module>
#     logistic = testClassifier(LogisticRegression(random_state=random_state),
#   File "/Users/yevgeniykostrov/Documents/Flatiron/Phase3_Project_Final/PredictRainKaggle/JupyterNotebooks/tools.py", line 165, in testClassifier
#     grid.fit(X_train,y_train)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 734, in __exit__
#     self._terminate_backend()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 764, in _terminate_backend
#     self._backend.terminate()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 551, in terminate
#     self._workers._temp_folder_manager._unlink_temporary_resources(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 627, in _unlink_temporary_resources
#     self._try_delete_folder(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 654, in _try_delete_folder
#     delete_folder(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/disk.py", line 136, in delete_folder
#     time.sleep(RM_SUBDIRS_RETRY_TIME)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3434, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 745, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 940, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/concurrent/futures/_base.py", line 434, in result
#     self._condition.wait(timeout)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 1188, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 708, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 1061, in __call__
#     self.retrieve()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 962, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-3d404dfb6435>", line 2, in <module>
#     logistic = testClassifier(LogisticRegression(random_state=random_state),
#   File "/Users/yevgeniykostrov/Documents/Flatiron/Phase3_Project_Final/PredictRainKaggle/JupyterNotebooks/tools.py", line 165, in testClassifier
#     grid.fit(X_train,y_train)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 734, in __exit__
#     self._terminate_backend()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 764, in _terminate_backend
#     self._backend.terminate()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 551, in terminate
#     self._workers._temp_folder_manager._unlink_temporary_resources(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 627, in _unlink_temporary_resources
#     self._try_delete_folder(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 654, in _try_delete_folder
#     delete_folder(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/disk.py", line 136, in delete_folder
#     time.sleep(RM_SUBDIRS_RETRY_TIME)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3434, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2922, in _run_cell
#     return runner(coro)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3145, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3356, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1210, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt

# %% [markdown]
# ***
# ## Tune up Random Forest
# ***

# %%
# create the grid for Random Forest, perform optimizaton and print results
param_grid_rf = [{'bootstrap':[True],'n_estimators':[3,5,10,20,30,50,80,120],
    'max_features':['auto'],
    'max_depth' : [5,10,20, 30, 40, 50 ,60 , 70],
    'criterion':['gini', 'entropy']},]
random_forest = testClassifier(RandomForestClassifier(random_state=random_state), param_grid=param_grid_rf, scoring=scoring, values=values)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 566
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Exception ignored in: <function _releaseLock at 0x7faa1000f3a0>
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/logging/__init__.py", line 227, in _releaseLock
#     if _lock:
# KeyboardInterrupt:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-50a799af774d>", line 6, in <module>
#     random_forest = testClassifier(RandomForestClassifier(random_state=random_state), param_grid=param_grid_rf, scoring=scoring, values=values)
#   File "/Users/yevgeniykostrov/Documents/Flatiron/Phase3_Project_Final/PredictRainKaggle/JupyterNotebooks/tools.py", line 165, in testClassifier
#     grid.fit(X_train,y_train)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 736, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 1188, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py", line 708, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/reusable_executor.py", line 177, in submit
#     return super(_ReusablePoolExecutor, self).submit(
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 1122, in submit
#     self._ensure_executor_running()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 1096, in _ensure_executor_running
#     self._adjust_process_count()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 1074, in _adjust_process_count
#     worker_exit_lock = self._context.BoundedSemaphore(1)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/context.py", line 322, in BoundedSemaphore
#     return BoundedSemaphore(value)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 156, in __init__
#     SemLock.__init__(self, SEMAPHORE, value, value)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 90, in __init__
#     resource_tracker.register(self._semlock.name, "semlock")
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 190, in register
#     self.ensure_running()
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 99, in ensure_running
#     with self._lock:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/yevgeniykostrov/opt/anaconda3/envs/learn-env/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-43-50a799af774d> in <module>
#       5     'criterion':['gini', 'entropy']},]
# ----> 6 random_forest = testClassifier(RandomForestClassifier(random_state=random_state), param_grid=param_grid_rf, scoring=scoring, values=values)
#
# ~/Documents/Flatiron/Phase3_Project_Final/PredictRainKaggle/JupyterNotebooks/tools.py in testClassifier(clf, param_grid, scoring, values, cv)
#     164                             return_train_score=True, verbose=1, n_jobs = -1)
# --> 165     grid.fit(X_train,y_train)
#     166     print("*"*50)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     530         """Schedule a func to be run"""
# --> 531         future = self._workers.submit(SafeFunction(func))
#     532         future.get = functools.partial(self.wrap_future_result, future)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/reusable_executor.py in submit(self, fn, *args, **kwargs)
#     176         with self._submit_resize_lock:
# --> 177             return super(_ReusablePoolExecutor, self).submit(
#     178                 fn, *args, **kwargs)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py in submit(self, fn, *args, **kwargs)
#    1121
# -> 1122             self._ensure_executor_running()
#    1123             return f
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py in _ensure_executor_running(self)
#    1095             if len(self._processes) != self._max_workers:
# -> 1096                 self._adjust_process_count()
#    1097             self._start_executor_manager_thread()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py in _adjust_process_count(self)
#    1073         for _ in range(len(self._processes), self._max_workers):
# -> 1074             worker_exit_lock = self._context.BoundedSemaphore(1)
#    1075             args = (self._call_queue, self._result_queue, self._initializer,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/context.py in BoundedSemaphore(self, value)
#     321             from .synchronize import BoundedSemaphore
# --> 322             return BoundedSemaphore(value)
#     323
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py in __init__(self, value)
#     155     def __init__(self, value=1):
# --> 156         SemLock.__init__(self, SEMAPHORE, value, value)
#     157
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py in __init__(self, kind, value, maxvalue)
#      89         # process shuts down we unlink the semaphore name
# ---> 90         resource_tracker.register(self._semlock.name, "semlock")
#      91         util.Finalize(self, SemLock._cleanup, (self._semlock.name,),
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/resource_tracker.py in register(self, name, rtype)
#     189         '''Register a named resource, and increment its refcount.'''
# --> 190         self.ensure_running()
#     191         self._send('REGISTER', name, rtype)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/externals/loky/backend/resource_tracker.py in ensure_running(self)
#      98         the resource created by its parent.'''
# ---> 99         with self._lock:
#     100             if self._fd is not None:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         stb = value._render_traceback_()
#    2045                     except Exception:
# -> 2046                         stb = self.InteractiveTB.structured_traceback(etype,
#    2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ***
# # HGBoost Tune Up
# ***

# %%
# create the grid for HGBoost, perform optimizaton and print results
param_grid_xgb = {
    'max_depth':range(2,10,1),
    'n_estimators': range(20,100,20),
    'learning_rate': [0.1, 0.01, 0.05]
}
xgboost = testClassifier(XGBClassifier(random_state=random_state),
                        param_grid=param_grid_xgb,
                        scoring=scoring,
                        values=values)

# %% [markdown]
# ***
# # Conclusion
# ***

# %% [markdown]
# # * All four models preformed better after tune up
# ## Here is the summary of preformance
# *Logistic Regression Classifier*
#
# After tuning hyper parameters for Logistic Regression classifier we have the following results:
#
# * Logistic Regression classifier went up from 93.6% to 100% on validation data.
# * Logistic Regression classifier achieves 100% on test data that I have not used for training.
# * The precision score went down from 85.5% to 75.7% on validation data.
# * The precision score on test data is 75.9%.
#
# *Random Forest Classifier*
#
# After tuning hyper parameters for Random Forest classifier we have the following results:
# * Random Forest classifier went up from 94.87% to 94.97% on validation data.
# * Random Forest classifier achieves 95% on test data that I have not used for training.
# * The precision score stays at 86% on validation data.
# * The precision score on test data is 86%.
#
# *HGBoost Classifier*
#
# After tuning hyper parameters for HGBoost classifier we have the following results:
# * HGBoost classifier went up from 94% to 97.7% on validation data.
# * HGBoost classifier achieves 97.7% on test data that I have not used for training.
# * The precision score went from 87% to 80.6% on validation data.
# * The precision score on test data is 80.6%.
#
# *Support Vector Machines Classifier*
#
# After tuning hyper parameters for Support Vector Machines classifier we have the following results:
# * Support Vector Machines classifier went up from 95.9% to 100% on validation data.
# * Support Vector Machines classifier achieves 100% on test data that I have not used for training.
# * The precision score went from 85.1% to 75.7% on validation data.
# * The precision score on test data is 75.9%.
# ***

# %% [markdown]
# ***
# # Comments on the performance after tuning
# ***
#
# * It seems that the best choice for the model is HGBoost since it has the best balance between recall score at 97.7% on the test data and precision score at 80.6% on the test data.
# * If one wants to neglect the precision score (labeling a lot of non-rainy days as rainy), then the best choice is Logistic Regression. Even though it is close in performance to Support Vector Machines, it is lighter and easier to retrain.
